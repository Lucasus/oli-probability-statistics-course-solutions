# %%
import matplotlib
import matplotlib.pyplot as plt
print(matplotlib.is_interactive())
# %config IPCompleter.greedy=True
import pandas as pd
df = pd.read_csv("datasets/height.csv", sep = ';', decimal=",")
df.describe(include='all')
# Out:
# True
#           gender     height      weight  Unnamed: 3  Unnamed: 4  Unnamed: 5
# count  81.000000  81.000000   81.000000         0.0         0.0         0.0
# mean    0.296296  68.012346  154.555556         NaN         NaN         NaN
# std     0.459468   4.148776   34.099853         NaN         NaN         NaN
# min     0.000000  54.000000   82.000000         NaN         NaN         NaN
# 25%     0.000000  66.000000  125.000000         NaN         NaN         NaN
# 50%     0.000000  68.000000  151.000000         NaN         NaN         NaN
# 75%     1.000000  71.000000  175.000000         NaN         NaN         NaN
# max     1.000000  75.000000  240.000000         NaN         NaN         NaN

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#set font size of labels on matplotlib plots
plt.rc('font', size=16)

#set style of plots
sns.set_style('white')

#define a custom palette
customPalette = ['#630C3A', '#39C8C6', '#D3500C', '#FFB139']
sns.set_palette(customPalette)
#sns.palplot(customPalette)

facet = sns.lmplot(data=df, x='height', y='weight', hue='gender', 
                   fit_reg=False, legend=True, legend_out=True, height=7)

import matplotlib.pyplot as plt
df.plot.scatter(x='height',y='weight',figsize=(8, 8));
