# %%
import matplotlib
import matplotlib.pyplot as plt
print(matplotlib.is_interactive())
# %config IPCompleter.greedy=True
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv("datasets/animals.csv", sep = ';', decimal=",")

# %%
df.describe(include='all')
# Out:
#              animal   gestation  longevity
# count            40   40.000000  40.000000
# unique           40         NaN        NaN
# top     bear, black         NaN        NaN
# freq              1         NaN        NaN
# mean            NaN  194.325000  13.150000
# std             NaN  143.387835   7.244981
# min             NaN   15.000000   1.000000
# 25%             NaN   66.750000   8.000000
# 50%             NaN  175.500000  12.000000
# 75%             NaN  262.250000  15.250000
# max             NaN  645.000000  40.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
#fig.set_size_inches(20, 10)
#df.plot.scatter(x='longevity',y='gestation',figsize=(8, 8));

df2 = df[df['animal'] != 'elephant']
print(df2['longevity'].corr(df2['gestation']))
sns.regplot(x='longevity', y='gestation', data=df,ax=ax1);
sns.regplot(x='longevity', y='gestation', data=df2,ax=ax2);
# Out:
# 0.5190389111466762
